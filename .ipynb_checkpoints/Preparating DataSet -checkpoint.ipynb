# %%
import numpy as np 
import pandas as pd

# %%
dataset_uk = pd.read_csv('Dataset/Diogenes-GI-Database-for-Website-UK.csv', encoding = 'utf-8')
dataset_uk.head()
# Out:
#    Diogenes food code Country food code                   Food name  \
# 0                   1            11-005                 Bran. wheat
# 1                   2            11-469  White bread. fried in lard
# 2                   3            11-091                   Rye bread
# 3                   4            11-456        Brown bread. average
# 4                   5            11-458     Chapatis. made with fat
#
#           English translation  Diogenes food group  CHO (g/100g)  GI value  \
# 0                 Bran. wheat                  6.1          26.8        70
# 1  White bread. fried in lard                  5.1          46.8        72
# 2                   Rye bread                  1.1          45.8        70
# 3        Brown bread. average                  1.1          42.1        73
# 4     Chapatis. made with fat                  5.1          48.3        50
#
#    GL  GI confidence level Source of the data on GI (1)     ...       \
# ...

# %%
#Columns don't need us 
columns_uk = [ 
           'Country food code', 
           'English translation', 
           'Source of the data on GI (2)', 
           'Source of the data on GI (1)',
           'Comment',
           'Diogenes food group',
           'Unnamed: 12', 'Unnamed: 13',
           'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
           'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
           'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
           'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
           'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
           'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
           'Unnamed: 38', 'Unnamed: 39'
          ]

# %% [markdown]
# # Delete usefull columns and rename column

# %%
dataset_uk.rename(index=str,columns={'Diogenes food code':'eat_id'}, inplace=True)
dataset_uk = dataset_uk.drop(columns_uk, axis='columns')
dataset_uk.head()
# Out:
#    eat_id                   Food name  CHO (g/100g)  GI value  GL  \
# 0       1                 Bran. wheat          26.8        70  19
# 1       2  White bread. fried in lard          46.8        72  34
# 2       3                   Rye bread          45.8        70  32
# 3       4        Brown bread. average          42.1        73  31
# 4       5     Chapatis. made with fat          48.3        50  24
#
#    GI confidence level
# 0                    5
# 1                    3
# 2                    5
# 3                    3
# 4                    3

# %%
dataset_uk.info()
print(dataset_uk.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4603 entries, 0 to 4602
# Data columns (total 6 columns):
# eat_id                 4603 non-null int64
# Food name              4603 non-null object
# CHO (g/100g)           4603 non-null float64
# GI value               4603 non-null int64
# GL                     4603 non-null int64
# GI confidence level    4603 non-null int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 251.7+ KB
# (4603, 6)

# %%
dataset_uk.columns
# Out:
# Index(['eat_id', 'Food name', 'CHO (g/100g)', 'GI value', 'GL',
#        'GI confidence level'],
#       dtype='object')

# %%
#Check all, column have data
dataset_uk.dropna().any()
# Out:
# eat_id                 True
# Food name              True
# CHO (g/100g)           True
# GI value               True
# GL                     True
# GI confidence level    True
# dtype: bool

# %%
dataset_uk.tail()
# Out:
#       eat_id                                          Food name  CHO (g/100g)  \
# 4598   51545  Uncle Ben's Express Wolemeal rice and vegetables           27.0
# 4599   51546                                            Oatibix          64.0
# 4600   51547                       chocolate and orange truffle          22.0
# 4601   51548               smoked haddck and cheese sauce (m&s)           6.0
# 4602   51549                              quorn korma escalopes          20.0
#
#       GI value  GL  GI confidence level
# 4598        63  17                    4
# 4599        55  35                    3
# 4600        45  10                    4
# 4601        45   3                    4
# 4602        45   9                    4

# %% [markdown]
# # Delete Duplicates

# %%
dataset_uk.drop_duplicates(keep=False, inplace=True)

# %%
dataset_uk.shape
# Out:
# (1233, 6)

# %%
dataset_uk['eat_id'] = range(1, dataset_uk.shape[0] + 1)

# %%
dataset_uk.head()
# Out:
#       eat_id                                     Food name  CHO (g/100g)  \
# 3370       1  Goats milk soft cheese. full fat. white rind           1.0
# 3371       2                      White bread. West Indian          58.8
# 3372       3                White bread. aerated. slimmers          50.9
# 3373       4          Homemade biscuits. rubbing-in method          61.7
# 3374       5                    Chickpeas/Bengal gram. raw          50.0
#
#       GI value  GL  GI confidence level
# 3370        34   0                    3
# 3371        72  42                    3
# 3372        72  37                    3
# 3373        63  39                    3
# 3374        28  14                    2

# %%
dataset_uk.tail()
# Out:
#       eat_id                                          Food name  CHO (g/100g)  \
# 4598    1229  Uncle Ben's Express Wolemeal rice and vegetables           27.0
# 4599    1230                                            Oatibix          64.0
# 4600    1231                       chocolate and orange truffle          22.0
# 4601    1232               smoked haddck and cheese sauce (m&s)           6.0
# 4602    1233                              quorn korma escalopes          20.0
#
#       GI value  GL  GI confidence level
# 4598        63  17                    4
# 4599        55  35                    3
# 4600        45  10                    4
# 4601        45   3                    4
# 4602        45   9                    4

# %% [markdown]
# # Reset Index

# %%
dataset_uk.reset_index(drop=True, inplace=True)

# %%
dataset_uk.head()
# Out:
#    eat_id                                     Food name  CHO (g/100g)  \
# 0       1  Goats milk soft cheese. full fat. white rind           1.0
# 1       2                      White bread. West Indian          58.8
# 2       3                White bread. aerated. slimmers          50.9
# 3       4          Homemade biscuits. rubbing-in method          61.7
# 4       5                    Chickpeas/Bengal gram. raw          50.0
#
#    GI value  GL  GI confidence level
# 0        34   0                    3
# 1        72  42                    3
# 2        72  37                    3
# 3        63  39                    3
# 4        28  14                    2

# %% [markdown]
# # Save File CSV

# %%
file_name = 'Eats_Names_Dataset.csv'
dataset_uk.to_csv(file_name, encoding='utf-8', index=False)
